# %%
sheet1 = pd.read_csv('sheet1.csv')

# %%
sheet1
# Out:
#         商品コード                        商品名       売上日    伝票No 得意先コード  \
# 0      2-001a             クローバーはしおき　深緑単品  20150401  199945   135a
# 1      2-001a             クローバーはしおき　深緑単品  20150402  199954   135b
# 2      2-001a             クローバーはしおき　深緑単品  20150406  199983   135m
# 3      2-001a             クローバーはしおき　深緑単品  20150422  200296   135a
# 4      2-001a             クローバーはしおき　深緑単品  20150428  200443   135k
# 5      2-001a             クローバーはしおき　深緑単品  20150508  200522   135a
# 6      2-001a             クローバーはしおき　深緑単品  20150508  200525   135h
# 7      2-001a             クローバーはしおき　深緑単品  20150512  200574   135m
# 8      2-001a             クローバーはしおき　深緑単品  20150522  200740   135a
# 9      2-001a             クローバーはしおき　深緑単品  20150529  200811   135c
# 10     2-001a             クローバーはしおき　深緑単品  20150611  200997   135a
# 11     2-001a             クローバーはしおき　深緑単品  20150629  201256   135h
# 12     2-001a             クローバーはしおき　深緑単品  20150703  201304   135k
# ...

# %%
sheet1['商品名']
# Out:
# 0                   クローバーはしおき　深緑単品
# 1                   クローバーはしおき　深緑単品
# 2                   クローバーはしおき　深緑単品
# 3                   クローバーはしおき　深緑単品
# 4                   クローバーはしおき　深緑単品
# 5                   クローバーはしおき　深緑単品
# 6                   クローバーはしおき　深緑単品
# 7                   クローバーはしおき　深緑単品
# 8                   クローバーはしおき　深緑単品
# 9                   クローバーはしおき　深緑単品
# 10                  クローバーはしおき　深緑単品
# 11                  クローバーはしおき　深緑単品
# 12                  クローバーはしおき　深緑単品
# 13                  クローバーはしおき　深緑単品
# 14                  クローバーはしおき　深緑単品
# 15                  クローバーはしおき　深緑単品
# 16                  クローバーはしおき　深緑単品
# 17                  クローバーはしおき　深緑単品
# 18                  クローバーはしおき　深緑単品
# 19                  クローバーはしおき　深緑単品
# 20                  クローバーはしおき　深緑単品
# 21                  クローバーはしおき　深緑単品
# 22                  クローバーはしおき　深緑単品
# 23                  クローバーはしおき　深緑単品
# 24                  クローバーはしおき　深緑単品
# 25                  クローバーはしおき　深緑単品
# 26                  クローバーはしおき　深緑単品
# ...

# %%
import pandas_profiling as pdp
# Out:
# /Users/a0082273/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/a0082273/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/a0082273/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/a0082273/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# ...

# %%
pdp.ProfileReport(sheet1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
len(sheet1['商品コード'].unique())
# Out:
# 527
